# %%
import numpy as n
import pandas as pn
import datetime as d
import time as t

a = n.array([1,2,3])
r = n.random.randn(4000)
s = n.random.randn(4000)
#plot(r,'.')
#scatter(r)
print r
print s
#plot(r,'.')
#plot(s,'.')
scatter(r,s)
scatter(r,s)
# Out:
# [ 0.03907969 -1.11976796 -2.21974358 ..., -0.07696919  0.74732267
#   0.4792864 ]
# [-0.325225    0.58195239 -0.69580237 ..., -0.52440568  1.18541862
#   0.65915443]

# %%
d1 = d.datetime(2014,10,1)
d2 = d.datetime(2014,11,1)
r = pn.date_range(d1,d2)
p2 = [1,20]

# %%
def g1(years=1, capital_initial=100, rate1=1, period1=250, period2=12, showPlot=True, debit_rate=2, debit_period=20):
    #years = 1
    p = array(range(1, period1 * years, 1))
    
    """
    capital_initial=100
    r1      = None
    rate1   = 1
    period1 = 250
    period2 = 12
    """
    
    rate2   = capital_initial * ( pow( pow( 1 + float(rate1) / 100,period1),1.0 / period2) - 1)
    print 'rate2:'+str(rate2)
    
    ret = 100 * pow(1 + float(rate1) / 100, p-1)
    z = zeros(len(ret))
    
    # ret
    tr1 = t.mktime([2014,10,1,0,0,0,0,0,0])
    dty = len(ret) - 1
    #print 'dty:'+str(dty)
    dta = (3600 * 24 * dty)
    
    tr2 = tr1 + dta
    d1 = d.datetime.fromtimestamp(tr1)
    d2 = d.datetime.fromtimestamp(tr2)    
    r = pn.date_range(d1,d2)
    
    ret2 = array([ret,z,z,z,z,z])
    """
    print 'ret2T0:'+str(len(ret2.T[0]))
    print 'z:'+str(len(z))
    print 'r:'+str(len(r))
    for i in ret2:
        print 'ret2leni:'+str(len(i))
    #print ret2
    """
    df = pn.DataFrame(ret2.T, index=r,columns=['balance_model','rate','balance_cummulative','steps','credit','debit'])
    
    df.loc[d.datetime(2014,10,1),'balance_cummulative'] = capital_initial
    df.loc[:,'rate'] = rate1
    df.loc[:,'debit'] = (p % debit_period == 0)
    
    df.loc[df.index[0],'balance_cummulative'] = capital_initial
    df.loc[df.index[0],'debit'] = 0
    for i in xrange(1,len(df.index)):
        #print i
        bc = df.loc[df.index[i-1],'balance_cummulative']
        cr = df.loc[df.index[i-1],'credit']
        db = df.loc[df.index[i-1],'debit']
        rc = df.loc[df.index[i-1],'rate']
        df.loc[df.index[i],'balance_cummulative'] = (bc+cr-db) * (1+rc/100)
        if df.loc[df.index[i],'debit']:
            df.loc[df.index[i],'debit'] = df.loc[df.index[i],'balance_cummulative'] * debit_rate / 100
        else:
            df.loc[df.index[i],'debit'] = 0
        ''
    
    step = int(float(period1) / period2)
    nb = (p / step)
    #print nb
    df.loc[:,'steps'] = capital_initial * pow(1 + float(rate2) / 100, nb)

    print 'Credits: '+str(toCurrency(sum(df.loc[:,'credit'])))
    print 'Debits: '+str(toCurrency(sum(df.loc[:,'debit'])))
    print 'Balance_model: '+str(toCurrency(df.loc[df.index[len(df)-1],'balance_model']))
    print 'Balance_cummulative: '+str(toCurrency(df.loc[df.index[len(df)-1],'balance_cummulative']))
    print 'Steps: '+str(toCurrency(df.loc[df.index[len(df)-1],'steps']))
    print 'cummul. + debits: '+str(toCurrency(df.loc[df.index[len(df)-1],'balance_cummulative']+sum(df.loc[:,'debit'])))
    
    print df    
    
    #plot(ret)
    if showPlot:
        plot(df)
        
    return df

df = g1(years=1, capital_initial=100, rate1=1, period1=250, period2=12,showPlot=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3d2f909ecd7e> in <module>()
#      78     return df
#      79
# ---> 80 df = g1(years=1, capital_initial=100, rate1=1, period1=250, period2=12,showPlot=False)
#
# <ipython-input-3-3d2f909ecd7e> in g1(years, capital_initial, rate1, period1, period2, showPlot, debit_rate, debit_period)
#      63     df.loc[:,'steps'] = capital_initial * pow(1 + float(rate2) / 100, nb)
#      64
# ---> 65     print 'Credits: '+str(toCurrency(sum(df.loc[:,'credit'])))
#      66     print 'Debits: '+str(toCurrency(sum(df.loc[:,'debit'])))
#      67     print 'Balance_model: '+str(toCurrency(df.loc[df.index[len(df)-1],'balance_model']))
#
# NameError: global name 'toCurrency' is not defined
# rate2:23.0349849514

# %%
rate1   = 0.568251887043
period1 = 20
period2 = 3
print ci * ( pow( pow( 1 + float(r1) / 100, p1), 1.0 / p2) - 1)
g1(years=1, capital_initial=100, period1=period1, period2=period2, rate1=rate1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-13e1142d9524> in <module>()
#       2 period1 = 20
#       3 period2 = 3
# ----> 4 print ci * ( pow( pow( 1 + float(r1) / 100, p1), 1.0 / p2) - 1)
#       5 g1(years=1, capital_initial=100, period1=period1, period2=period2, rate1=rate1)
#
# NameError: name 'ci' is not defined

# %%
# compounding @ 12%/month
g1(years=10, capital_initial=100, rate1=0.568251887043, period1=250, period2=12, debit_rate=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-963f20930e65> in <module>()
#       1 # compounding @ 12%/month
# ----> 2 g1(years=10, capital_initial=100, rate1=0.568251887043, period1=250, period2=12, debit_rate=1)
#
# NameError: name 'g1' is not defined

# %%
g1(years=1, capital_initial=100, rate1=2, period1=250, period2=12)
# Out:
# rate2:51.0672227198
# Credits:  0
# Debits: 574
# Balance_model: 13578
# Balance_cummulative: 10655
# Steps: 14126
# cummul. + debits: 11229
#            balance_model rate balance_cummulative     steps credit     debit
# 2014-10-01           100    2                 100       100      0         0
# 2014-10-02           102    2                 102       100      0         0
# 2014-10-03        104.04    2              104.04       100      0         0
# 2014-10-04      106.1208    2            106.1208       100      0         0
# 2014-10-05      108.2432    2            108.2432       100      0         0
# 2014-10-06      110.4081    2            110.4081       100      0         0
# 2014-10-07      112.6162    2            112.6162       100      0         0
# 2014-10-08      114.8686    2            114.8686       100      0         0
# 2014-10-09      117.1659    2            117.1659       100      0         0
# 2014-10-10      119.5093    2            119.5093       100      0         0
# 2014-10-11      121.8994    2            121.8994       100      0         0
# 2014-10-12      124.3374    2            124.3374       100      0         0
# 2014-10-13      126.8242    2            126.8242       100      0         0
# 2014-10-14      129.3607    2            129.3607       100      0         0
# 2014-10-15      131.9479    2            131.9479       100      0         0
# 2014-10-16      134.5868    2            134.5868       100      0         0
# 2014-10-17      137.2786    2            137.2786       100      0         0
# 2014-10-18      140.0241    2            140.0241       100      0         0
# 2014-10-19      142.8246    2            142.8246       100      0         0
# 2014-10-20      145.6811    2            145.6811  151.0672      0  2.913622
# 2014-10-21      148.5947    2            145.6228  151.0672      0         0
# 2014-10-22      151.5666    2            148.5353  151.0672      0         0
# 2014-10-23       154.598    2             151.506  151.0672      0         0
# 2014-10-24      157.6899    2            154.5361  151.0672      0         0
# 2014-10-25      160.8437    2            157.6269  151.0672      0         0
# 2014-10-26      164.0606    2            160.7794  151.0672      0         0
# 2014-10-27      167.3418    2             163.995  151.0672      0         0
# 2014-10-28      170.6886    2            167.2749  151.0672      0         0
# 2014-10-29      174.1024    2            170.6204  151.0672      0         0
# 2014-10-30      177.5845    2            174.0328  151.0672      0         0
# 2014-10-31      181.1362    2            177.5134  151.0672      0         0
# 2014-11-01      184.7589    2            181.0637  151.0672      0         0
# 2014-11-02      188.4541    2             184.685  151.0672      0         0
# 2014-11-03      192.2231    2            188.3787  151.0672      0         0
# 2014-11-04      196.0676    2            192.1463  151.0672      0         0
# 2014-11-05       199.989    2            195.9892  151.0672      0         0
# 2014-11-06      203.9887    2             199.909  151.0672      0         0
# 2014-11-07      208.0685    2            203.9071  151.0672      0         0
# 2014-11-08      212.2299    2            207.9853  151.0672      0         0
# 2014-11-09      216.4745    2             212.145  228.2131      0    4.2429
# 2014-11-10       220.804    2            212.0601  228.2131      0         0
# 2014-11-11        225.22    2            216.3013  228.2131      0         0
# 2014-11-12      229.7244    2            220.6274  228.2131      0         0
# 2014-11-13      234.3189    2            225.0399  228.2131      0         0
# 2014-11-14      239.0053    2            229.5407  228.2131      0         0
# 2014-11-15      243.7854    2            234.1315  228.2131      0         0
# 2014-11-16      248.6611    2            238.8141  228.2131      0         0
# 2014-11-17      253.6344    2            243.5904  228.2131      0         0
# 2014-11-18       258.707    2            248.4622  228.2131      0         0
# 2014-11-19      263.8812    2            253.4315  228.2131      0         0
# 2014-11-20      269.1588    2            258.5001  228.2131      0         0
# 2014-11-21       274.542    2            263.6701  228.2131      0         0
# 2014-11-22      280.0328    2            268.9435  228.2131      0         0
# 2014-11-23      285.6335    2            274.3224  228.2131      0         0
# 2014-11-24      291.3461    2            279.8088  228.2131      0         0
# 2014-11-25      297.1731    2             285.405  228.2131      0         0
# 2014-11-26      303.1165    2            291.1131  228.2131      0         0
# 2014-11-27      309.1789    2            296.9354  228.2131      0         0
# 2014-11-28      315.3624    2            302.8741  228.2131      0         0
# 2014-11-29      321.6697    2            308.9316  344.7551      0  6.178631
#                      ...  ...                 ...       ...    ...       ...
#
# [249 rows x 6 columns]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-907-5c7b24530d8d> in <module>()
# ----> 1 g1(years=1, capital_initial=100, rate1=2, period1=250, period2=12)
#
# <ipython-input-854-0ec58639ef47> in g1(years, capital_initial, rate1, period1, period2, showPlot, debit_rate, debit_period)
#      76
#      77     print df
# ---> 78     p.Series(df)
#      79
#      80     #plot(ret)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'Series'

# %%
s = p.Series(array([1,1,2,3]), index=[12,13,14,15])
s2 = p.Series(array([11,222,33,22]), index=[12,13,14,15])
#print s
#print s2
#print s.combine_first(s2)
df2 = p.DataFrame([s,s2,s,s2,s,s,s2,s2])
#print df2.T
dm = p.DataFrame(df2.T)
dm1 = dm.ix[:,[0,1,2]]
dm2 = dm.ix[:,[3,4,5]]
print dm1
print dm2
#print dm1.append(dm2)
print dm1.combineAdd(dm2).combineAdd(dm1)
#print p.DataFrame([dm1,dm2], index=dm1.index)
#p.DataFrame([dm1,dm2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2d752f4ed41b> in <module>()
# ----> 1 s = p.Series(array([1,1,2,3]), index=[12,13,14,15])
#       2 s2 = p.Series(array([11,222,33,22]), index=[12,13,14,15])
#       3 #print s
#       4 #print s2
#       5 #print s.combine_first(s2)
#
# NameError: name 'p' is not defined

# %%
da1 = df.ix[:,[2,3,4,5]]
da2 = da1.copy()
#da2
#print list(da2.index)
da2.reindex(index=list(da2.index), columns=list(['steps','s','c','d']))
#da2.reindex(da2.index, columns=)
#print p.DataFrame(da1.ix[:,0])

#print da1.get_values()

da1.combineAdd(da2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ac3773113788> in <module>()
# ----> 1 da1 = df.ix[:,[2,3,4,5]]
#       2 da2 = da1.copy()
#       3 #da2
#       4 #print list(da2.index)
#       5 da2.reindex(index=list(da2.index), columns=list(['steps','s','c','d']))
#
# NameError: name 'df' is not defined
