# %%
# source: https://www.youtube.com/watch?v=bzl4hCH2CdY
import flask

app = flask.Flask(__name__)

@app.route('/')
def root():
    return 'everything is running'

@app.route('/test')
def test():
    hdir = '/ml/bin/'
    #svg = hdir+'Blank_US_Map.svg'
    svg = hdir+'images/BlankMap-World-Subdivisions.svg'
    fp = open(svg)
    svg = fp.read()
    fp.close()
    #print t
    
    d3 = """
<script>

svg = d3.select('svg');
//svg.select('path[id="FL"]').style('fill', 'blue') //
//svg.select('path[id="FL"]').style('fill', 'blue') //

/*d3.json('/test2', function(error, states) {
    states.forEach(function() {
        //svg.select('');
        //console.log('test123123');
    });
});*/
</script>
"""
    
    b = ''
    b += '<html>'
    b += '<head>'
    b += '<script src="http://d3js.org/d3.v3.min.js" charset="utf-8"></script>'
    b += '<script src="//code.jquery.com/jquery-1.11.2.min.js"></script>'
    b += '</head>'
    b += '<body>'
    b += svg
    b += d3
    b += '</body>'
    b += '</html>'
    return b

#@app.route('/high/poverty/stastes')
#def high_poverty_states():
#    donors_choose_url = 'http://'

if __name__ == "__main__":
    print 'check: http://127.0.0.1:5000'
    app.run()
# Out:
# check: http://127.0.0.1:5000

# %%
from qoreliquid import *

#url = 'http://<server>/api/1.2/xml/Autocomplete?key=<key>&query=cinque'
url = 'http://free.rome2rio.com/api/1.2/json/Search?key=7L3e3oOO&oName=London&dName=Paris'
#url = 'http://google.com'
print fetchURL(url)
# Out:
# {u'airports': [{u'timeZone': u'Europe/London', u'code': u'LCY', u'name': u'London City', u'countryCode': u'GB', u'pos': u'51.50389,0.0498'}, {u'timeZone': u'Europe/Paris', u'code': u'ORY', u'name': u'Paris Orly', u'countryCode': u'FR', u'pos': u'48.72882,2.36884'}, {u'timeZone': u'Europe/London', u'code': u'LHR', u'name': u'London Heathrow', u'countryCode': u'GB', u'pos': u'51.47034,-0.45342'}, {u'timeZone': u'Europe/Paris', u'code': u'CDG', u'name': u'Paris CDG', u'countryCode': u'FR', u'pos': u'49.004,2.5711'}, {u'timeZone': u'Europe/London', u'code': u'LGW', u'name': u'London Gatwick', u'countryCode': u'GB', u'pos': u'51.1565,-0.16145'}, {u'timeZone': u'Europe/London', u'code': u'LTN', u'name': u'London Luton', u'countryCode': u'GB', u'pos': u'51.87967,-0.37544'}, {u'timeZone': u'Europe/London', u'code': u'SOU', u'name': u'Southampton', u'countryCode': u'GB', u'pos': u'50.9504,-1.36157'}], u'places': [{u'kind': u'metropolis', u'name': u'London', u'countryCode': u'GB', u'pos': u'51
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-1-280e9aaafee7> in <module>()
#       1 import html2text
# ----> 2 html = open("foobar.html").read()
#       3 print html2text.html2text(html)
#
# IOError: [Errno 2] No such file or directory: 'foobar.html'
