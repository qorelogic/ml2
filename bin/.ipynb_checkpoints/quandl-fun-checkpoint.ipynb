# %%
import Quandl as q
d = q.get("BCHARTS/BTCEUSD", authtoken="WVsyCxwHeYZZyhf5RHs2")
print d.tail(5)
plot(d.ix[:,['Close']])
# Out:
#                Open     High      Low    Close  Volume (BTC)  \
# Date
# 2014-12-10  347.375  348.000  339.984  340.000   4375.770519
# 2014-12-11  340.000  356.995  332.510  341.492   7896.979757
# 2014-12-12  341.878  349.864  340.053  347.000   3402.266722
# 2014-12-13  345.575  346.002  339.067  342.573   2310.605361
# 2014-12-14  342.559  346.960  336.411  343.014   4797.354095
#
#             Volume (Currency)  Weighted Price
# Date
# 2014-12-10     1505156.900660      343.975283
# 2014-12-11     2738354.038640      346.759663
# 2014-12-12     1174928.330740      345.336926
# 2014-12-13      792466.738076      342.969315
# 2014-12-14     1637037.886000      341.237660

# %%
qcodes = []
qcodes.append('BNP/USDRUB')
qcodes.append('BNP/USDARS')
print qcodes
d = q.get(qcodes, authtoken="WVsyCxwHeYZZyhf5RHs2")
print d.tail(5)
plot(d.ix[1000:len(d)+1,:])
# Out:
# ['BNP/USDRUB', 'BNP/USDARS']
#             BNP.USDRUB - USD/RUB  BNP.USDARS - USD/ARS
# Date
# 2014-12-10               54.1706                8.5473
# 2014-12-11               54.3910                8.5528
# 2014-12-12               55.2373                8.5515
# 2014-12-13               57.0435                8.5535
# 2014-12-14               57.0435                8.5541
# [<matplotlib.lines.Line2D at 0xa5a55acc>,
#  <matplotlib.lines.Line2D at 0xa5a55d6c>]

# %%
ds = d
#ds = (ds - n.mean(ds)) / n.std(ds) # standard score normalization
ds = (ds - n.min(ds))/(n.max(ds) - n.min(ds)) # feature scaled normalization
#ds = 1/(1+n.power(n.e, -ds)) # sigmoid function
print ds.tail(5)
h = ['BNP.USDRUB - USD/RUB', 'BNP.USDARS - USD/ARS']
i = 0
plot(ds.ix[1000:len(ds)+1,h[i]])
legend(h[i],2)
# Out:
#             BNP.USDRUB - USD/RUB  BNP.USDARS - USD/ARS
# Date
# 2014-12-10              0.008040              0.999101
# 2014-12-11              0.008077              0.999828
# 2014-12-12              0.008219              0.999656
# 2014-12-13              0.008520              0.999921
# 2014-12-14              0.008520              1.000000

# %%
qcodes = []
qcodes.append('BNP/USDRUB')
qcodes.append('SGE/RUSIR') # russian interest rate (premium)
qcodes.append('YC/RUS') # russian yeild curve
print qcodes
d = q.get(qcodes, authtoken="WVsyCxwHeYZZyhf5RHs2")
print d.tail(5)
plot(d.ix[1000:len(d)+1,:])
# Out:
# ['BNP/USDRUB', 'SGE/RUSIR', 'YC/RUS']
#             BNP.USDRUB - USD/RUB  SGE.RUSIR - Value  YC.RUS - Short-Term  \
# Date
# 2014-12-11               54.3910                NaN                 9.48
# 2014-12-12               55.2373                NaN                 9.91
# 2014-12-13               57.0435                NaN                  NaN
# 2014-12-14               57.0435                NaN                  NaN
# 2014-12-15                   NaN                NaN                14.84
#
#             YC.RUS - Medium-Term  YC.RUS - Long-Term
# Date
# 2014-12-11                 11.69               11.36
# 2014-12-12                 12.09               12.00
# 2014-12-13                   NaN                 NaN
# 2014-12-14                   NaN                 NaN
# 2014-12-15                 11.96               11.64
# [<matplotlib.lines.Line2D at 0xa898304c>,
#  <matplotlib.lines.Line2D at 0xa897dd8c>,
#  <matplotlib.lines.Line2D at 0xa897db6c>,
#  <matplotlib.lines.Line2D at 0xa897d9cc>,
#  <matplotlib.lines.Line2D at 0xa897d82c>]

# %%
ds = d
#ds = 1/(1+n.power(n.e, -ds))
#ds = (ds - n.mean(ds)) / n.std(ds)
#print ds
ds = ds.ix[2010:len(d)+1,:]
print ds.columns
#print ds #.tail(5)
plot(ds.ix[:,:])
legend(ds.columns, 2)
# Out:
# Index([u'BNP.USDRUB - USD/RUB', u'SGE.RUSIR - Value', u'YC.RUS - Short-Term', u'YC.RUS - Medium-Term', u'YC.RUS - Long-Term'], dtype='object')

# %%
import numpy as n
from pylab import rcParams
rcParams['figure.figsize'] = 20, 5

def plotB(d):
    r = range(0,len(d))
    #plot(r)
    res = n.power(2,r)
    ic = 10
    #res
    
    hds = []
    hds.append('Close')
    
    d['ex1'] = ic * n.power(1 + 0.37 / 100, r)
    #res1 = n.power(1 + 0.6 / 100, r)
    hds.append('ex1')
    
    d['ex2'] = ic * n.power(1 + 0.29 / 100, r)
    #res2 = n.power(1 + 0.48 / 100, r)
    hds.append('ex2')
    
    d['ex3'] = ic * n.power(1 + 0.19 / 100, r)
    hds.append('ex3')
    
    res = d.ix[0:700,hds]
    #print res
    plot(res)
    legend(['close','ex1','ex2','ex3'])
    
plotB(d)

# %%
res
y = res.ix[:,'Close']
y
# Out:
# Date
# 2011-08-14    10.00
# 2011-08-15    11.90
# 2011-08-16    11.10
# 2011-08-17    10.50
# 2011-08-18    10.49
# 2011-08-19    11.30
# 2011-08-20    11.29
# 2011-08-21    11.01
# 2011-08-22    10.90
# 2011-08-23    10.75
# 2011-08-24    10.70
# 2011-08-25     9.65
# 2011-08-26     8.00
# 2011-08-27     8.80
# 2011-08-28     8.60
# ...
# 2013-06-29    89.599
# 2013-06-30    90.207
# 2013-07-01    81.008
# 2013-07-02    85.400
# 2013-07-03    77.448
# 2013-07-04    79.283
# 2013-07-05    66.396
# 2013-07-06    65.501
# 2013-07-07    74.000
# 2013-07-08    73.099
# 2013-07-09    72.248
# 2013-07-10    80.190
# 2013-07-11    82.500
# 2013-07-12    86.999
# 2013-07-13    88.990
# Name: Close, Length: 700

# %%
#print d.ix[:,['Close']]
#print len(d)
a = n.array(d.ix[0:len(d),['Close']]).transpose().tolist()[0]
b = n.array(d.ix[1:len(d),['Close']]).transpose().tolist()[0]
#print len(a)
#print len(b)
#print a[0]
de = p.DataFrame(index=d.index)
#print len(de)
b.insert(len(de),0)

de['a'] = a
de['b'] = b
# tomorrow opens higher
de['c'] = n.array((de.ix[:,'a'] - de.ix[:,'b']) < 0)
#print 
print de.tail(10)
# Out:
#                   a        b      c
# Date
# 2014-12-05  369.992  369.126  False
# 2014-12-06  369.126  367.569  False
# 2014-12-07  367.569  356.989  False
# 2014-12-08  356.989  345.910  False
# 2014-12-09  345.910  340.000  False
# 2014-12-10  340.000  341.492   True
# 2014-12-11  341.492  347.000   True
# 2014-12-12  347.000  342.573  False
# 2014-12-13  342.573  343.014   True
# 2014-12-14  343.014    0.000  False

# %%
import Quandl as q
def quandlget(t):
    return q.get(t, authtoken="WVsyCxwHeYZZyhf5RHs2")

BCHAIN_NTRAN = quandlget("BCHAIN/NTRAN")
BCHAIN_MKTCP = quandlget("BCHAIN/MKTCP")
BCHAIN_TOTBC = quandlget("BCHAIN/TOTBC")
BCHAIN_NTRAT = quandlget("BCHAIN/NTRAT")
BCHAIN_HRATE = quandlget("BCHAIN/HRATE")
BCHAIN_ETRVU = quandlget("BCHAIN/ETRVU")
BCHAIN_NADDU = quandlget("BCHAIN/NADDU")
BCHAIN_AVBLS = quandlget("BCHAIN/AVBLS")
BCHAIN_MIREV = quandlget("BCHAIN/MIREV")

# %%
"""
plot(BCHAIN_HRATE)
plot(BCHAIN_NTRAN)
plot(BCHAIN_MKTCP)
plot(BCHAIN_TOTBC)
plot(BCHAIN_NTRAT)
plot(BCHAIN_HRATE)
plot(BCHAIN_ETRVU)
plot(BCHAIN_NADDU)
plot(BCHAIN_AVBLS)
plot(BCHAIN_MIREV)
"""
# Out:
# '\nplot(BCHAIN_HRATE)\nplot(BCHAIN_NTRAN)\nplot(BCHAIN_MKTCP)\nplot(BCHAIN_TOTBC)\nplot(BCHAIN_NTRAT)\nplot(BCHAIN_HRATE)\nplot(BCHAIN_ETRVU)\nplot(BCHAIN_NADDU)\nplot(BCHAIN_AVBLS)\nplot(BCHAIN_MIREV)\n'

# %%
import pandas as p
dd = p.DataFrame()
dd['BCHAIN_NTRAN'] = BCHAIN_NTRAN.ix[:,'Value']
dd['BCHAIN_MKTCP'] = BCHAIN_MKTCP.ix[:,'Value']
dd['BCHAIN_TOTBC'] = BCHAIN_TOTBC.ix[:,'Value']
dd['BCHAIN_NTRAT'] = BCHAIN_NTRAT.ix[:,'Value']
dd['BCHAIN_HRATE'] = BCHAIN_HRATE.ix[:,'Value']
dd['BCHAIN_ETRVU'] = BCHAIN_ETRVU.ix[:,'Value']
dd['BCHAIN_NADDU'] = BCHAIN_NADDU.ix[:,'Value']
dd['BCHAIN_AVBLS'] = BCHAIN_AVBLS.ix[:,'Value']
dd['BCHAIN_MIREV'] = BCHAIN_MIREV.ix[:,'Value']
dd['btceusd'] = d.ix[:,['Close']]
dd['tomorrowHiger'] = de['c']

dd = (dd- n.mean(dd))/n.std(dd)
dd = 1 / (1 + n.power(n.e, -dd))
print dd.tail(3)
dd.to_csv('test-2131211212.csv')
print len(dd)
plot(dd,'.')
legend(['BCHAIN_NTRAN','BCHAIN_MKTCP','BCHAIN_TOTBC','BCHAIN_NTRAT','BCHAIN_HRATE','BCHAIN_ETRVU','BCHAIN_NADDU','BCHAIN_AVBLS','BCHAIN_MIREV','btceusd','tomorrowHigher'],2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-f475da9ac13e> in <module>()
#      11 dd['BCHAIN_MIREV'] = BCHAIN_MIREV.ix[:,'Value']
#      12 dd['btceusd'] = d.ix[:,['Close']]
# ---> 13 dd['tomorrowHiger'] = de['c']
#      14
#      15 dd = (dd- n.mean(dd))/n.std(dd)
#
# NameError: name 'de' is not defined

# %%
def computeCost(X, y, theta):
    X = n.array(X)
    #print X
    m = len(y)
    J = 0
    J = 1.0/(2*m) * n.sum(n.power(n.dot(X,theta)-y,2))
    return J

print computeCost( n.array([1, 2, 1, 3, 1, 4, 1, 5]).reshape(4,2), n.array([7, 6, 5, 4]).reshape(4,1), n.array([0.1,0.2]).reshape(2,1) )
# 11.945
print computeCost( n.array([1,2,3,1,3,4,1,4,5,1,5,6]).reshape(4,3), n.array([7, 6, 5, 4]).reshape(4,1), n.array([0.1,0.2,0.3]).reshape(3,1))
# 7.0175
# Out:
# 11.945
# 7.0175

# %%
res = p.DataFrame(n.array([1, 2, 1, 3, 1, 4, 1, 5]).reshape(4,2))

print n.array([1,5,1,2,1,4,1,5]).reshape(4,2)
print n.array([1,6,4,2]).reshape(4,1)
print n.array([0,0]).reshape(2,1)
# Out:
# [[1 5]
#  [1 2]
#  [1 4]
#  [1 5]]
# [[1]
#  [6]
#  [4]
#  [2]]
# [[0]
#  [0]]

# %%
def gradientDescent(X, y, theta, alpha, num_iters):
    m = len(y)
    J_history = n.zeros(num_iters)
    for iter in range(0,num_iters):
        theta = theta - (float(alpha)/m) * n.dot((n.dot(X,theta)-y).transpose(),X).transpose()
        J_history[iter] = computeCost(X, y, theta)
    
    return [theta, J_history]
    
#[theta, J_history] = gradientDescent(n.array([1,5,1,2,1,4,1,5]).reshape(4,2), n.array([1,6,4,2]).reshape(4,1), n.array([0,0]).reshape(2,1),0.01,1000);
#print theta
#print J_history
#theta =
#    5.2148
#   -0.5733
#>>J_hist(1)
#ans  =  5.9794
#>>J_hist(1000)
#ans = 0.85426

#[theta, J_hist] = gradientDescent(n.array([3,5,1,2,9,4,1,5]).reshape(4,2),n.array([1,6,4,2]).reshape(4,1), n.array([0,0]).reshape(2,1), 0.01,1000);
#print theta
#print J_hist
#>>theta
#theta =
#    0.2588
#    0.3999

# %%
# gradient descent
data = p.read_csv('/coursera/ml-007/programming-exercises/mlclass-ex1/ex1data1.txt', header=None)
#print data
X = data.ix[:,0]
y = data.ix[:,1]
m = len(y)

plot(X,y,'.')

X = p.DataFrame()
X[0] = ones(m)
X[1] = data.ix[:,0]

theta = n.zeros(2)

#% Some gradient descent settings
iterations = 1500;
alpha = 0.01;
    
#% compute and display initial cost
computeCost(X, y, theta)

#% run gradient descent
[theta, J_hist] = gradientDescent(X, y, theta, alpha, iterations);

#% print theta to screen
print 'Theta found by gradient descent: '
#print '%f %f \n', theta(1), theta(2)
print theta
# Out:
# Theta found by gradient descent:
# [-3.63029144  1.16636235]

# %%
#print n.dot(X,theta)
#plot(X.ix[:,1],y,'.')
#plot(,y,'-')
print n.dot(n.array([1, 3.5]), theta) * 1e4
print n.dot(n.array([1, 7]), theta) * 1e4
# Out:
# 4519.7678677
# 45342.4501294

# %%
theta0_vals = linspace(-10, 10, 100)
theta1_vals = linspace(-1, 4, 100)
J_vals = n.zeros(len(theta0_vals)*len(theta1_vals)).reshape(len(theta0_vals),len(theta1_vals))
for i in range(0,len(theta0_vals)):
    for j in range(0,len(theta1_vals)):
        t = n.array([theta0_vals[i], theta1_vals[j]])
        #print theta0_vals[i]
        #print theta1_vals[j]
        #print t
        cc = computeCost(X, y, t)
        J_vals[i][j] = cc
        #print cc
        #print t
#print J_vals
contour(theta0_vals, theta1_vals, J_vals, logspace(-2, 3, 20))
plot(t[0], t[1], 'x')
