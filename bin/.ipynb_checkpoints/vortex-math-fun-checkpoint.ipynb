# %%
import numpy as n

# inspired from: Randy Powell: Intro to Vortex Math [Full] [1/2]
#                https://www.youtube.com/watch?v=Fbyc9JW3vtk
# finds the digital root traditional recursive loop method
# todo: find vectorized soln
# explode nu
def dr(nu):
    str2 = []
    for i in xrange(0, len(str(nu))):
        str2.append(int(str(nu)[i]))
    nu = int(n.sum(n.array(str2)))
    print 'exploded: '+str(str2)
    print 'digital root: '+str(nu)
    return nu

def digitalRoot(nu):
    print 'digital root of: ' + str(nu)
    
    nu = dr(nu)
    lnu = len(str(nu))
    #print lnu
    if lnu > 1:
        nu = digitalRoot(nu)
        
    return nu
    
#print n.array([1,2,3,4])
    
print digitalRoot(10298)
print digitalRoot(987987)
print digitalRoot(9879879879868759)
print digitalRoot(9786987687765765)
print digitalRoot(67547654)
print digitalRoot(76546754)
print digitalRoot(20)
# Out:
# digital root of: 10298
# exploded: [1, 0, 2, 9, 8]
# digital root: 20
# digital root of: 20
# exploded: [2, 0]
# digital root: 2
# 2
# digital root of: 987987
# exploded: [9, 8, 7, 9, 8, 7]
# digital root: 48
# digital root of: 48
# exploded: [4, 8]
# digital root: 12
# digital root of: 12
# exploded: [1, 2]
# digital root: 3
# 3
# digital root of: 9879879879868759
# exploded: [9, 8, 7, 9, 8, 7, 9, 8, 7, 9, 8, 6, 8, 7, 5, 9]
# digital root: 124
# digital root of: 124
# exploded: [1, 2, 4]
# digital root: 7
# 7
# digital root of: 9786987687765765
# exploded: [9, 7, 8, 6, 9, 8, 7, 6, 8, 7, 7, 6, 5, 7, 6, 5]
# digital root: 111
# digital root of: 111
# exploded: [1, 1, 1]
# digital root: 3
# 3
# digital root of: 67547654
# exploded: [6, 7, 5, 4, 7, 6, 5, 4]
# digital root: 44
# digital root of: 44
# exploded: [4, 4]
# digital root: 8
# 8
# digital root of: 76546754
# exploded: [7, 6, 5, 4, 6, 7, 5, 4]
# digital root: 44
# digital root of: 44
# exploded: [4, 4]
# digital root: 8
# 8
# digital root of: 20
# exploded: [2, 0]
# digital root: 2
# 2

# %%
r = n.arange(0,1000)
for i in r:
    print r[i]
    #print r[i]    
print r[0]
print r
